# %%
# !git clone https://github.com/ZeinyLing/Deep-Generative-Models-Agent-Driven-Integration-Project
# Out:
# Cloning into 'Deep-Generative-Models-Agent-Driven-Integration-Project'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 104 (delta 49), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (104/104), 1.09 MiB | 11.70 MiB/s, done.
# Resolving deltas: 100% (49/49), done.

# %%
# !ls
# Out:
# Deep-Generative-Models-Agent-Driven-Integration-Project  sample_data

# %%
# %cd Deep-Generative-Models-Agent-Driven-Integration-Project
# Out:
# /content/Deep-Generative-Models-Agent-Driven-Integration-Project

# %%
# !pip install -r requirements.txt

# %%
import os

os.environ["OPENROUTER_API_KEY"] = "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"
os.environ["OPENROUTER_MODEL"] = "opencode/gpt-4o-mini"  #big-pickle

# %%
# !python app.py --share
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://9aed9ce5e72b1372c3.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# [Warning] LLM prompt generation failed. Using short fallback prompt.
# 400 Client Error: Bad Request for url: https://openrouter.ai/api/v1/chat/completions
# [Info] Loading diffusion model: runwayml/stable-diffusion-inpainting
# [Info] Device: cuda
# model_index.json: 100% 548/548 [00:00<00:00, 3.27MB/s]
# ...
